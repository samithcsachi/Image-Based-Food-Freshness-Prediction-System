# %%
import sys
sys.path.append('../src')
from utils import plot_class_distribution, show_random_images, show_image_by_path
from config import Config
from utils import raw_img_dir
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys
#       2 sys.path.append('../src')
# ----> 3 from utils import plot_class_distribution, show_random_images, show_image_by_path
#       4 from config import Config
#       5 from utils import raw_img_dir
#
# File d:\SAMITH\Github\Image-Based-Food-Freshness-Prediction-System\notebooks\../src\utils.py:2
#       1 import os
# ----> 2 from src.config import Config
#       3 from pathlib import Path
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'src'

# %%
image_paths = raw_img_dir(Config.RAW_DATA_DIR, Config.CATEGORY_NAMES)

# %%
class_counts = {cls: len(paths) for cls, paths in image_paths.items()}
plot_class_distribution(class_counts)

# %%
show_random_images(image_paths, num_per_class=5)

# %%
show_image_by_path(image_paths["Fresh"][0])
